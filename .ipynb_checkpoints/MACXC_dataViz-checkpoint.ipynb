# %% [markdown]
# # Data Summary and Visualization of the MAC PACK '19

# %% [markdown]
# The "Mac Pack" is what the Macalester Men's Cross Country Team is fondly known as, given to our current coach Matt Haugen. He deems the "Mac Pack Era" as the time in which he has been head coach, which has been since the early 2000s. The team nickname is a play-on-words to indicate that we run in packs, which is important in cross country since we the goal is to try to minimize the number of points the team collects in a meet.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import qgrid
from IPython.display import display, HTML

sns.set(style="whitegrid")

# %% [markdown]
# This reads in the csv file that was created from the python script dedicated to web scraping meet results and creating a full data frame containing information on all the meets that the men's cross country team competed in this year. It drops an unused variable left over from that process.

# %%
MeetInfo = pd.read_csv("MeetTimes_19.csv")
MeetInfo = MeetInfo.drop(['Unnamed: 0'], axis=1)
MeetInfo
# Out:
#        PL  TEAMPLACE       LASTNAME FIRSTNAME  YEAR        TEAM Avg. Mile  \
# 0     8.0          1          Lepak      Jake  SR-4  Macalester    5:20.6
# 1    13.0          2        Johnson    Adrian  JR-3  Macalester    5:25.4
# 2    16.0          3          Hayes    August  FR-1  Macalester    5:30.4
# 3    17.0          4  Reyes Herrera     Edwin  SR-4  Macalester    5:31.5
# 4    19.0          5          Mayse     Smith  SO-2  Macalester    5:31.7
# ..    ...        ...            ...       ...   ...         ...       ...
# 89  166.0         12      Hernandez   Armando  SR-4  Macalester    5:52.5
# 90  169.0         13          Peske      Cole  FR-1  Macalester    5:53.4
# 91  183.0         14        Rachlin     Peter  FR-1  Macalester    6:00.1
# 92  198.0         15           Levy    Elijah  JR-3  Macalester    6:07.9
# 93  210.0         16         Baldus      JoJo  SR-4  Macalester    6:19.8
#
#        TIME  SCORE                      MEET  DATE      1K             2.4K  \
# 0   21:22.1    8.0  Twin Cities Invitational  2019     NaN              NaN
# 1   21:41.4   13.0  Twin Cities Invitational  2019     NaN              NaN
# 2   22:01.4   16.0  Twin Cities Invitational  2019     NaN              NaN
# 3   22:05.9   17.0  Twin Cities Invitational  2019     NaN              NaN
# 4   22:06.7   19.0  Twin Cities Invitational  2019     NaN              NaN
# ..      ...    ...                       ...   ...     ...              ...
# 89  29:12.6    NaN                      MIAC  2019  3:38.5  8:48.0 (5:09.5)
# 90  29:16.9    NaN                      MIAC  2019  3:21.7  8:13.5 (4:51.9)
# 91  29:50.3    NaN                      MIAC  2019  3:29.5  8:38.0 (5:08.5)
# 92  30:29.2    NaN                      MIAC  2019  3:27.2  8:31.2 (5:04.0)
# 93  31:28.3    NaN                      MIAC  2019  3:52.8  9:22.2 (5:29.4)
#
#                 4.5K                 7K   5k   3K 5.8K
# 0                NaN                NaN  NaN  NaN  NaN
# 1                NaN                NaN  NaN  NaN  NaN
# 2                NaN                NaN  NaN  NaN  NaN
# 3                NaN                NaN  NaN  NaN  NaN
# 4                NaN                NaN  NaN  NaN  NaN
# ..               ...                ...  ...  ...  ...
# 89  16:25.4 (7:37.5)   25:42.3 (9:16.9)  NaN  NaN  NaN
# 90  15:52.9 (7:39.4)   25:39.8 (9:47.0)  NaN  NaN  NaN
# 91  16:29.3 (7:51.3)   26:14.5 (9:45.3)  NaN  NaN  NaN
# 92  16:32.3 (8:01.1)  26:46.2 (10:14.0)  NaN  NaN  NaN
# 93  17:36.6 (8:14.5)  27:41.2 (10:04.7)  NaN  NaN  NaN
#
# [94 rows x 18 columns]

# %%
g = sns.FacetGrid(MeetInfo, col="LASTNAME", hue = "FIRSTNAME", col_wrap=5)
(g.map(plt.plot,"MEET", "TEAMPLACE", marker=".")
.set_axis_labels("", "Team Place")
.set_xticklabels([]))

# %% [markdown]
# Uses `plotnine` module to create plot using ggplot commands
# Interesting to note that seom syntax still follows python commands

# %%
from plotnine import *
(ggplot(MeetInfo, aes(x = "MEET", y = "TEAMPLACE", label = "LASTNAME", color = "LASTNAME")) + 
    geom_text(size = 6) +
    theme_minimal() +
    theme(axis_text_x=element_text(angle = 45), legend_position ="none") +
    scale_y_continuous(breaks = list(range(1,18, 1))) + 
    scale_x_discrete(limits = ["Twin Cities Invitational", "Summit Cup", "Running of the Cows (Carleton)",
                              "Blugold Invitational", "Jim Drews Invitational (Lacrosse)", "MIAC"]))
# Out:
# <ggplot: (307121333)>

# %% [markdown]
# * uses `value_counts` to find the number of times a runner appears in the dataset, which also reflects how many meets a runner participated in this year
# * Converted into a dataframe, column renamed to "Count"

# %%
runnerMeets = pd.DataFrame(MeetInfo.LASTNAME.value_counts())
runnerMeets.columns = ["Count"]
runnerMeets
# Out:
#                 Count
# Mayse               6
# O'Donnell-Hoff      6
# Reyes Herrera       6
# Johnson             6
# Baumeister          6
# Hernandez           6
# Jarka-Sellers       6
# Peske               6
# Milner              6
# Lepak               6
# Bildsten            6
# Kerr                5
# Hayes               4
# Rachlin             4
# Lewis-Norelle       3
# Baldus              3
# Levy                3
# Hunsanger           3
# Morefield           3

# %% [markdown]
# * Takes the dataframe above, filters so that it only has those where count = 6, then gets the names of those runners by using `.index` and saving them into a list
# * This will be used to calculate total score runner contributed

# %%
scorers = list(runnerMeets[runnerMeets.Count == 6].index)
scorers
# Out:
# ['Mayse',
#  "O'Donnell-Hoff",
#  'Reyes Herrera',
#  'Johnson',
#  'Baumeister',
#  'Hernandez',
#  'Jarka-Sellers',
#  'Peske',
#  'Milner',
#  'Lepak',
#  'Bildsten']

# %% [markdown]
# * First: Filters original `MeetInfo` dataset to only include those in which runners were in the top 7 (i.e. scored)
# * Then, it filters again to only include runners in which participated in all meets by referencing `scorers` list above with those names
# * Groups by Last Name, sums the total score they accumulated for all meets, and changes the index into columns using `.reset.index()`

# %%
top7Scores = MeetInfo[MeetInfo.TEAMPLACE.isin(range(1,8))]
top7Scores2 = top7Scores[top7Scores.LASTNAME.isin(scorers)]
top7Scores2 = top7Scores2.groupby("LASTNAME").sum()[['SCORE']].reset_index()
top7Scores2
# Out:
#          LASTNAME  SCORE
# 0   Jarka-Sellers  196.0
# 1         Johnson  226.0
# 2           Lepak  216.0
# 3           Mayse  259.0
# 4  O'Donnell-Hoff  426.0
# 5           Peske  231.0
# 6   Reyes Herrera  383.0

# %%
sns.barplot(x="LASTNAME", y="SCORE", data=top7Scores2)

# %% [markdown]
# * Doing this to show that only 5 members consistently were on the scoring team, so can only plot their total scores for the year since they would be higher than those who only sometimes were on the scoring team.

# %%
top7Scores.groupby("LASTNAME").count()[["SCORE"]].reset_index()
# Out:
#          LASTNAME  SCORE
# 0           Hayes      2
# 1       Hunsanger      1
# 2   Jarka-Sellers      2
# 3         Johnson      6
# 4            Kerr      5
# 5           Lepak      6
# 6           Mayse      6
# 7  O'Donnell-Hoff      6
# 8           Peske      2
# 9   Reyes Herrera      6

# %%
top7Scores2 = top7Scores2[~top7Scores2.LASTNAME.isin(["Jarka-Sellers", "Peske"])]
# top7Scores2.drop([0,5])
sns.barplot(x="LASTNAME", y="SCORE", data=top7Scores2)

# %%
def get_sec(time_str):
    """Get Seconds from time."""
    m_1 = time_str.split(":")
    m = m_1[0]
    s = m_1[1]
    return float(m)*60 + float(s)

def get_min(time_float):
    """Get minutes from seconds."""
    minutes1 = str(time_float/60)
    minutes = float(minutes1[0:2])
    sec = round(float(minutes1[2:]) * 60, ndigits=1)
    sec2 = sec/100
    return minutes + sec2

print(get_sec("5:15.3"))
print(get_min(315.3))
# Out:
# 315.3
# 158.0

# %%
seconds = []
for i in MeetInfo["TIME"]:
    if i == "DNF":
        seconds.append(None)
    else:
        seconds.append(get_sec(i))

MeetInfo.insert(8, "TIME_SEC", seconds)

# %%
Min = []
for i in MeetInfo["TIME_SEC"]:
    if pd.isna(i) == True:
        Min.append(None)
    else:
        Min.append(get_min(i))

MeetInfo.insert(9, "TIME_FINAL", Min)

MeetInfo
# Out:
#        PL  TEAMPLACE       LASTNAME FIRSTNAME  YEAR        TEAM Avg. Mile  \
# 0     8.0          1          Lepak      Jake  SR-4  Macalester    5:20.6
# 1    13.0          2        Johnson    Adrian  JR-3  Macalester    5:25.4
# 2    16.0          3          Hayes    August  FR-1  Macalester    5:30.4
# 3    17.0          4  Reyes Herrera     Edwin  SR-4  Macalester    5:31.5
# 4    19.0          5          Mayse     Smith  SO-2  Macalester    5:31.7
# ..    ...        ...            ...       ...   ...         ...       ...
# 89  166.0         12      Hernandez   Armando  SR-4  Macalester    5:52.5
# 90  169.0         13          Peske      Cole  FR-1  Macalester    5:53.4
# 91  183.0         14        Rachlin     Peter  FR-1  Macalester    6:00.1
# 92  198.0         15           Levy    Elijah  JR-3  Macalester    6:07.9
# 93  210.0         16         Baldus      JoJo  SR-4  Macalester    6:19.8
#
#        TIME  TIME_SEC  TIME_FINAL  SCORE                      MEET  DATE  \
# 0   21:22.1    1282.1      21.221    8.0  Twin Cities Invitational  2019
# 1   21:41.4    1301.4      21.414   13.0  Twin Cities Invitational  2019
# 2   22:01.4    1321.4      22.014   16.0  Twin Cities Invitational  2019
# 3   22:05.9    1325.9      22.059   17.0  Twin Cities Invitational  2019
# 4   22:06.7    1326.7      22.067   19.0  Twin Cities Invitational  2019
# ..      ...       ...         ...    ...                       ...   ...
# 89  29:12.6    1752.6      29.126    NaN                      MIAC  2019
# 90  29:16.9    1756.9      29.169    NaN                      MIAC  2019
# 91  29:50.3    1790.3      29.503    NaN                      MIAC  2019
# 92  30:29.2    1829.2      30.292    NaN                      MIAC  2019
# 93  31:28.3    1888.3      31.283    NaN                      MIAC  2019
#
#         1K             2.4K              4.5K                 7K   5k   3K  \
# 0      NaN              NaN               NaN                NaN  NaN  NaN
# 1      NaN              NaN               NaN                NaN  NaN  NaN
# 2      NaN              NaN               NaN                NaN  NaN  NaN
# 3      NaN              NaN               NaN                NaN  NaN  NaN
# 4      NaN              NaN               NaN                NaN  NaN  NaN
# ..     ...              ...               ...                ...  ...  ...
# 89  3:38.5  8:48.0 (5:09.5)  16:25.4 (7:37.5)   25:42.3 (9:16.9)  NaN  NaN
# 90  3:21.7  8:13.5 (4:51.9)  15:52.9 (7:39.4)   25:39.8 (9:47.0)  NaN  NaN
# 91  3:29.5  8:38.0 (5:08.5)  16:29.3 (7:51.3)   26:14.5 (9:45.3)  NaN  NaN
# 92  3:27.2  8:31.2 (5:04.0)  16:32.3 (8:01.1)  26:46.2 (10:14.0)  NaN  NaN
# 93  3:52.8  9:22.2 (5:29.4)  17:36.6 (8:14.5)  27:41.2 (10:04.7)  NaN  NaN
#
#    5.8K
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# ..  ...
# 89  NaN
# 90  NaN
# 91  NaN
# 92  NaN
# 93  NaN
#
# [94 rows x 20 columns]

# %%
(ggplot(MeetInfo, aes(x = "MEET", y = "TIME_FINAL", color = "LASTNAME", group = "LASTNAME")) + 
    geom_point() +
    geom_line() +
    theme_minimal() +
    facet_wrap(facets="LASTNAME") +
    theme(axis_text_x=element_text(angle = 45), legend_position ="none") +
    scale_x_discrete(limits = ["Twin Cities Invitational", "Summit Cup", "Running of the Cows (Carleton)",
                              "Blugold Invitational", "Jim Drews Invitational (Lacrosse)", "MIAC"]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/layer.py:452: PlotnineWarning: geom_point : Removed 1 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (307378109)>

# %%
def get_mile(time_float):
    """Get minutes from seconds."""
    minutes1 = str(time_float/60)
    if minutes1[1] == ".": 
        minutes = float(minutes1[0])
        sec = round(float(minutes1[1:]) * 60, ndigits=1)
        sec2 = sec/100
    else:
        minutes1 = str(time_float/60)
        minutes = float(minutes1[0:2])
        sec = round(float(minutes1[2:]) * 60, ndigits=1)
        sec2 = sec/100
    return minutes + sec2

#### Can probably use this above too

print(get_sec("25:20.6"))
print(get_mile(1520.6))
# Out:
# 1520.6
# 25.206

# %%
pace_sec = []

for i in MeetInfo["Avg. Mile"]:
    if pd.isna(i) == True:
        pace_sec.append(None)
    else:
        pace_sec.append(get_sec(i))

MeetInfo.insert(7, "AVGMILE_SEC", pace_sec)
        
pace = []
for i in MeetInfo["AVGMILE_SEC"]:
    if pd.isna(i) == True:
        pace.append(None)
    else:
        pace.append(get_mile(i))

MeetInfo.insert(8, "MILEPACE", pace)
MeetInfo
# Out:
#        PL  TEAMPLACE       LASTNAME FIRSTNAME  YEAR        TEAM Avg. Mile  \
# 0     8.0          1          Lepak      Jake  SR-4  Macalester    5:20.6
# 1    13.0          2        Johnson    Adrian  JR-3  Macalester    5:25.4
# 2    16.0          3          Hayes    August  FR-1  Macalester    5:30.4
# 3    17.0          4  Reyes Herrera     Edwin  SR-4  Macalester    5:31.5
# 4    19.0          5          Mayse     Smith  SO-2  Macalester    5:31.7
# ..    ...        ...            ...       ...   ...         ...       ...
# 89  166.0         12      Hernandez   Armando  SR-4  Macalester    5:52.5
# 90  169.0         13          Peske      Cole  FR-1  Macalester    5:53.4
# 91  183.0         14        Rachlin     Peter  FR-1  Macalester    6:00.1
# 92  198.0         15           Levy    Elijah  JR-3  Macalester    6:07.9
# 93  210.0         16         Baldus      JoJo  SR-4  Macalester    6:19.8
#
#     AVGMILE_SEC  MILE PACE     TIME  ...  SCORE                      MEET  \
# 0         320.6      5.206  21:22.1  ...    8.0  Twin Cities Invitational
# 1         325.4      5.254  21:41.4  ...   13.0  Twin Cities Invitational
# 2         330.4      5.304  22:01.4  ...   16.0  Twin Cities Invitational
# 3         331.5      5.315  22:05.9  ...   17.0  Twin Cities Invitational
# 4         331.7      5.317  22:06.7  ...   19.0  Twin Cities Invitational
# ..          ...        ...      ...  ...    ...                       ...
# 89        352.5      5.525  29:12.6  ...    NaN                      MIAC
# 90        353.4      5.534  29:16.9  ...    NaN                      MIAC
# 91        360.1      6.001  29:50.3  ...    NaN                      MIAC
# 92        367.9      6.079  30:29.2  ...    NaN                      MIAC
# 93        379.8      6.198  31:28.3  ...    NaN                      MIAC
#
#     DATE      1K             2.4K              4.5K                 7K   5k  \
# 0   2019     NaN              NaN               NaN                NaN  NaN
# 1   2019     NaN              NaN               NaN                NaN  NaN
# 2   2019     NaN              NaN               NaN                NaN  NaN
# 3   2019     NaN              NaN               NaN                NaN  NaN
# 4   2019     NaN              NaN               NaN                NaN  NaN
# ..   ...     ...              ...               ...                ...  ...
# 89  2019  3:38.5  8:48.0 (5:09.5)  16:25.4 (7:37.5)   25:42.3 (9:16.9)  NaN
# 90  2019  3:21.7  8:13.5 (4:51.9)  15:52.9 (7:39.4)   25:39.8 (9:47.0)  NaN
# 91  2019  3:29.5  8:38.0 (5:08.5)  16:29.3 (7:51.3)   26:14.5 (9:45.3)  NaN
# 92  2019  3:27.2  8:31.2 (5:04.0)  16:32.3 (8:01.1)  26:46.2 (10:14.0)  NaN
# 93  2019  3:52.8  9:22.2 (5:29.4)  17:36.6 (8:14.5)  27:41.2 (10:04.7)  NaN
#
#      3K 5.8K
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# ..  ...  ...
# 89  NaN  NaN
# 90  NaN  NaN
# 91  NaN  NaN
# 92  NaN  NaN
# 93  NaN  NaN
#
# [94 rows x 22 columns]

# %%
(ggplot(MeetInfo, aes(x = "MEET", y = "MILE PACE", color = "LASTNAME", group = "LASTNAME")) + 
    geom_point() +
    geom_line() +
    theme_minimal() +
    facet_wrap(facets="LASTNAME") +
    theme(axis_text_x=element_text(angle = 45), legend_position ="none") +
    scale_x_discrete(limits = ["Twin Cities Invitational", "Summit Cup", "Running of the Cows (Carleton)",
                              "Blugold Invitational", "Jim Drews Invitational (Lacrosse)", "MIAC"]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotnine/layer.py:452: PlotnineWarning: geom_point : Removed 1 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (309314045)>
